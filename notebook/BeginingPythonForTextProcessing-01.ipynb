# %% [markdown]
# # The First Code

# %%
# This is a simple code to greet
greeting = "Hello World"
print(greeting)
# Out:
# Hello World

# %% [markdown]
# # Programming Syntax

# %%
"""This is a simple program to print
a given number as even or odd number"""
def even(x):
  if(x % 2 == 0):
    # Even number
    print("Even")
  else:
    # Odd number
    print("Odd")

even(5)
# Out:
# Odd

# %% [markdown]
# # Variables

# %%
PI = 3.14

# %%
a_number = 42
print(type(a_number))
a_number = str(a_number)
print(type(a_number))
a_number = float(a_number)
print(type(a_number))
# Out:
# <type 'int'>
# <type 'str'>
# <type 'float'>

# %%
anumber = "42"
print(type(anumber))
# Out:
# <type 'str'>

# %% [markdown]
# #Number

# %%
anInteger = 42
aFloat = 3.14
aComplex = 0.5 + 14.315j

print(type(anInteger))
print(type(aFloat))
print(type(aComplex))
# Out:
# <type 'int'>
# <type 'float'>
# <type 'complex'>

# %%
x = 40
y = 3.0
print("x * y = " + str(x * y))
print("x / y = " + str(x / y))
print("x // y = " + str(x // y))
print("x % y = " + str(x % y))
print("x + y = " + str(x + y))
print("x - y = " + str(x - y))
print(x * y)
print("x * y = " + x * y)
# Out:
# x * y = 120.0
# x / y = 13.3333333333
# x // y = 13.0
# x % y = 1.0
# x + y = 43.0
# x - y = 37.0
# 120.0
# TypeErrorTraceback (most recent call last)
# <ipython-input-16-6a610431786a> in <module>()
#       8 print("x - y = " + str(x - y))
#       9 print(x * y)
# ---> 10 print("x * y = " + x * y)
#
# TypeError: cannot concatenate 'str' and 'float' objects

# %%
print(anInteger + aComplex)
# Out:
# (42.5+14.315j)

# %%
aVeryLargeInteger = 99999999999999999999999999999999999
aVerySmallFloat = 0.000000000000000000000001

print(aVeryLargeInteger + aVerySmallFloat)
# Out:
# 1e+35

# %%
binaryLiteral = 0b00101010
decimalLiteral = 42
ocatalLiteral = 0o52
hexadecimalLiteral = 0x2A

print(binaryLiteral)
print(oct(decimalLiteral))
print(hex(ocatalLiteral))
print(bin(hexadecimalLiteral))
# Out:
# 42
# 052
# 0x2a
# 0b101010

# %% [markdown]
# #Boolean

# %%
def trueTest(x):
  if (x == True):
    return True
  else:
    return False

print(trueTest(not False))

# %%
print(True and False)
print(True or False)
print(True == (not False))
print(True != False)
# Out:
# False
# True
# True
# True

# %% [markdown]
# #String

# %%
a_string = "This is a beautiful world"
print("you are " + a_string[10:19])
# Out:
# you are beautiful

# %%
m_string = """Chaos reigns within.
Reflect, repent, and reboot.
Order shall return."""
print(m_string)
# Out:
# Chaos reigns within.
# Reflect, repent, and reboot.
# Order shall return.

# %%
r_string = r"Großer Bruder\t1984"
a_string = "Großer Bruder\t1984"
print(r_string)
print(a_string)
# Out:
# Großer Bruder\t1984
# Großer Bruder	1984

# %% [markdown]
# #List

# %%
a_list = [42, 3.14, "Hello World", "python"]
print(a_list[0:3])
# Out:
# [42, 3.14, 'Hello World']

# %%
a_list.append("java")
a_list[-2]
# Out:
# 'python'

# %%
print(a_list[:])
a_list.append("java")
print(a_list[:])
a_list.remove("java")
print(a_list[:])
a_list.remove(a_list[1])
# Out:
# [42, 'Hello World', 'python', 'java']
# [42, 'Hello World', 'python', 'java', 'java']
# [42, 'Hello World', 'python', 'java']

# %%
print(a_list)
# Out:
# [42, 'python', 'java']

# %%
b_list = []
print(b_list)
# Out:
# []

# %%
b_list.append(2)
b_list.append(3)
print(b_list)
# Out:
# [2, 3]

# %%
print(b_list.pop())
# Out:
# 3

# %%
print(b_list[:])
# Out:
# [2]

# %%
b_list.append(5)
c_list = a_list + b_list
print(c_list)
# Out:
# [42, 'python', 'java', 2, 5]

# %%
print(c_list.index('python'))
# Out:
# 1

# %%
c_list.insert(2, "itb")
print(c_list)
# Out:
# [42, 'python', 'itb', 'java', 2, 5]

# %%
c_list[1] = "Hello universe"
print(c_list)
# Out:
# [42, 'Hello universe', 'itb', 'java', 2, 5]

# %% [markdown]
# #Tuple

# %%
a_tuple = (42, 3.14, "Hello World", "python", ["java", "c"])
print(a_tuple[1:-1])
# Out:
# (3.14, 'Hello World', 'python')

# %%
a_tuple[1] = 2.5
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-41-c3ea225acf07> in <module>()
# ----> 1 a_tuple[1] = 2.5
#
# TypeError: 'tuple' object does not support item assignment

# %%
a_tuple[-1][1] = "r"
print(a_tuple)
# Out:
# (42, 3.14, 'Hello World', 'python', ['java', 'r'])

# %%
a_tuple[-1][0] = "c++"
print(a_tuple)
# Out:
# (42, 3.14, 'Hello World', 'python', ['c++', 'r'])

# %%
a_tuple[-1].append = "c"
print(a_tuple)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-44-8ba8956536da> in <module>()
# ----> 1 a_tuple[-1].append = "c"
#       2 print(a_tuple)
#
# AttributeError: 'list' object attribute 'append' is read-only

# %% [markdown]
# #Set

# %%
a_set = {42, 3.14, "Hello World", 2, 5}
print(a_set)
# Out:
# set([42, 'Hello World', 5, 2, 3.14])

# %%
a_set.add(3.14)
print(a_set)
# Out:
# set([42, 'Hello World', 5, 2, 3.14])

# %%
a_set.add(3)
a_set
# Out:
# {2, 3, 3.14, 5, 42, 'Hello World'}

# %%
b_set = a_set.copy()
b_set.discard(2)
print(b_set)
# Out:
# set([3, 5, 3.14, 42, 'Hello World'])

# %%
c_set = a_set.difference(b_set)
print(c_set)
# Out:
# set([2])

# %%
d_set = a_set.union(c_set)
print(d_set)
# Out:
# set([2, 3, 5, 3.14, 42, 'Hello World'])

# %%
print(a_set.issubset(d_set))
# Out:
# True

# %% [markdown]
# #Dictionary

# %%
a_dict = { 40131 : "Cipaganti",
           40132 : "Taman Sari"}
print(a_dict)
# Out:
# {40131: 'Cipaganti', 40132: 'Taman Sari'}

# %%
a_dict.keys()
# Out:
# [40131, 40132]

# %%
a_dict[40135] = "Sadang Serang"
print(a_dict)
# Out:
# {40131: 'Cipaganti', 40132: 'Taman Sari', 40135: 'Sadang Serang'}

# %%
a_dict[40135] = "Dago"
print(a_dict)
# Out:
# {40131: 'Cipaganti', 40132: 'Taman Sari', 40135: 'Dago'}

# %%
print(40135 in a_dict)
# Out:
# True

# %%
b_dict = {40133 : "Sadang Serang"}
a_dict.update(b_dict)
print(a_dict)
# Out:
# {40131: 'Cipaganti', 40132: 'Taman Sari', 40133: 'Sadang Serang', 40135: 'Dago'}

# %%
a_list = a_dict.items()
print(a_list)
# Out:
# [(40131, 'Cipaganti'), (40132, 'Taman Sari'), (40133, 'Sadang Serang'), (40135, 'Dago')]

# %%
a_keys = a_dict.keys()
a_values = a_dict.values()
print(a_keys)
print(a_values)
# Out:
# [40131, 40132, 40133, 40135]
# ['Cipaganti', 'Taman Sari', 'Sadang Serang', 'Dago']

# %%
b_pair = zip(a_keys, a_values)
print(b_pair)
# Out:
# [(40131, 'Cipaganti'), (40132, 'Taman Sari'), (40133, 'Sadang Serang'), (40135, 'Dago')]

# %%
b_dict = dict(b_pair)
print(b_dict)
# Out:
# {40131: 'Cipaganti', 40132: 'Taman Sari', 40133: 'Sadang Serang', 40135: 'Dago'}

# %% [markdown]
# #Conditional

# %%
if(x < 0):
  print("negative")
elif(x == 0):
  print("zero")
else:
  print("positive")

# %% [markdown]
# #Iteration

# %%
for i in range(1, 5):
  print(i)

# %%
i = 1
while(i < 5):
  print(i)
  i += 1

# %% [markdown]
# # Method

# %%
def greet(x):
  print("Hello " + x)

# %%
greet("World")

# %%
def greet_args(greet, *args, **names):
  for name in names:
    print(greet),
    for arg in args:
      print(arg),
    print(names[name])

# %%
greetArgs("Selamat", "Pagi", "Siang", "Sore", "Malam", name = "Dunia")

# %% [markdown]
# # Function

# %%
def fGreet(x):
  return "Hello " + x

# %%
greet_str = fGreet("World")
print(greet_str)
# Out:
# Hello World

# %% [markdown]
# #Input/Output

# %%
with open("hamlet-gutenberg.txt") as f:
  first_four = f.read(4)
  print(first_four)

# %%
with open("hamlet-gutenberg.txt") as f:
  lines = f.readlines()
  
  print(lines)

# %%
print("Hello {name}, {greet}".format(name = "World", greet="Good afternoon"))

# %%
a = 42
b = 3
print("%d * %d = %d" %(a, b, (a * b)))

# %%
with open("test.txt", "w") as wf:
  wf.write("Hello world")

# %% [markdown]
# #Module

# %%
if __name__ == "__main__":
    import sys
    fib(int(sys.argv[1]))

# %% [markdown]
# #Help

# %%
help(dict)
# Out:
# Help on class dict in module __builtin__:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __contains__(...)
#  |      D.__contains__(k) -> True if D has a key k, else False
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
# ...

# %%
dir(dict)
# Out:
# ['__class__',
#  '__cmp__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'has_key',
#  'items',
#  'iteritems',
#  'iterkeys',
#  'itervalues',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values',
#  'viewitems',
#  'viewkeys',
#  'viewvalues']
